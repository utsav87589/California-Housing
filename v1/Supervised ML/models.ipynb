# %% [markdown]
# ## ML/DL based models

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### data loading

# %%
df_trees = pd.read_csv('../data Cleaned/housing_trees.csv')
df_trees.drop('Unnamed: 0', axis = 1, inplace = True)
df_trees.head()
# Out:
#    longitude  latitude  housing_median_age  median_income  median_house_value  \
# 0    -122.23     37.88                41.0         8.3252            452600.0
# 1    -122.22     37.86                21.0         8.3014            358500.0
# 2    -122.24     37.85                52.0         7.2574            352100.0
# 3    -122.25     37.85                52.0         5.6431            341300.0
# 4    -122.25     37.85                52.0         3.8462            342200.0
#
#    ocean_proximity  rooms_per_bedroom  population_per_household  \
# 0                2                  6                         2
# 1                2                  6                         2
# 2                2                  7                         2
# 3                2                  5                         2
# 4                2                  5                         2
#
#    bedroom_per_household  room_per_household
# 0                      1                   6
# 1                      0                   6
# 2                      1                   8
# 3                      1                   5
# 4                      1                   6

# %%
# corr = df_trees.corr()['median_house_value'].sort_values(ascending = False)
# print(corr)

# %%
df_distance = pd.read_csv('../data Cleaned/housing_distance.csv')
df_distance.drop('Unnamed: 0', axis = 1, inplace = True)
df_distance.head()
# Out:
#    longitude  latitude  housing_median_age  median_house_value  \
# 0   0.211155  0.567481            0.784314            0.902266
# 1   0.212151  0.565356            0.392157            0.708247
# 2   0.210159  0.564293            1.000000            0.695051
# 3   0.209163  0.564293            1.000000            0.672783
# 4   0.209163  0.564293            1.000000            0.674638
#
#    ocean_proximity  rooms_per_bedroom  population_per_household  \
# 0                2                  6                         2
# 1                2                  6                         2
# 2                2                  7                         2
# 3                2                  5                         2
# 4                2                  5                         2
#
#    bedroom_per_household  room_per_household  median_income
# 0                      1                   6       1.000000
# 1                      0                   6       1.000000
# 2                      1                   8       0.877586
# 3                      1                   5       0.667939
# 4                      1                   6       0.434579

# %%
# corr = df_distance.corr()['median_house_value'].sort_values(ascending = False)
# print(corr)

# %% [markdown]
# ### making the train and the test data

# %%
from sklearn.model_selection import train_test_split

# %%
X_trees = df_trees.drop('median_house_value', axis = 1)
y_trees = df_trees.median_house_value

# %%
X_distance = df_distance.drop('median_house_value', axis = 1)
y_distance = df_distance.median_house_value

# %%
X_train_trees, X_test_trees, y_train_trees, y_test_trees = train_test_split(X_trees, y_trees, random_state = 42, test_size = 0.25)
X_train_distance, X_test_distance, y_train_distance, y_test_distance = train_test_split(X_distance, y_distance, random_state = 42, test_size = 0.25)

# %%
print(f"{X_train_trees.shape} : {y_train_trees.shape} :: {X_test_trees.shape} : {y_test_trees.shape}")
# Out:
# (15480, 9) : (15480,) :: (5160, 9) : (5160,)

# %%
print(f"{X_train_distance.shape} : {y_train_distance.shape} :: {X_test_distance.shape} : {y_test_distance.shape}")
# Out:
# (15480, 9) : (15480,) :: (5160, 9) : (5160,)

# %% [markdown]
# ### writing the metrices and functions

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, root_mean_squared_error

# %%
def metrices(y_test, y_pred) : 
    print(f"r2 score : {r2_score(y_test, y_pred)}")
    print(f"MAE : {mean_absolute_error(y_test, y_pred)}")
    print(f"RMSE : {root_mean_squared_error(y_test, y_pred)}")
    print(f"MSE : {mean_squared_error(y_test, y_pred)}")

# %%
def plot(y_test, y_pred) : 
    plt.figure(figsize=(10,6))
    plt.subplot(1, 2, 1)
    plt.scatter(y_test, y_pred, color='blue', alpha=0.5, label='Predicted')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()],
             color='red', linewidth=2, label='Perfect Prediction Line')
    plt.xlabel('Actual Values (y_test)')
    plt.ylabel('Predicted Values (y_pred)')
    plt.legend()
    plt.grid(True)
   
    plt.subplot(1, 2, 2)
    plt.plot(y_test, label='Actual', color='blue', marker='o')
    plt.plot(y_pred, label='Predicted', color='red', marker='x')
    plt.xlabel('Index')
    plt.ylabel('Target Value')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Testing the models

# %%
import joblib
scaler = joblib.load('../scalers/scaler_for_target.pkl')

# %%
def plot_and_pred_distance(X_test, y_test, X_train, y_train, model) : 
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred = scaler.inverse_transform(np.array(y_pred).reshape(-1, 1))
    y_test = scaler.inverse_transform(np.array(y_test).reshape(-1, 1))
    metrices(y_test, y_pred)
    plot(y_test, y_pred)

# %%
### for the distance based models, we must use the inverse scaler in order to make the 
### comparison fair, otherwise no matter what but the variance in that the case of the 
### tree based models will always look higher than that of distance based models

# %% [markdown]
# ### Distance based models

# %% [markdown]
# ### 1. Linear regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
plot_and_pred_distance(X_test_distance, y_test_distance, X_train_distance, y_train_distance, model = lr)
# Out:
# r2 score : 0.5761006935510993
# MAE : 53825.90785106171
# RMSE : 74894.00756758172
# MSE : 5609112369.532989

# %% [markdown]
# ### 2. SVR

# %%
from sklearn.svm import SVR
svr = SVR()
plot_and_pred_distance(X_test_distance, y_test_distance, X_train_distance, y_train_distance, model = svr)
# Out:
# r2 score : 0.66533703215511
# MAE : 47680.25056685246
# RMSE : 66545.63081798195
# MSE : 4428320980.963148

# %% [markdown]
# ### 3. KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
plot_and_pred_distance(X_test_distance, y_test_distance, X_train_distance, y_train_distance, model = knn)
# Out:
# r2 score : 0.65222913310871
# MAE : 45627.97802325582
# RMSE : 67836.3256251313
# MSE : 4601767074.318846

# %% [markdown]
# ### ------------Probablity based model-----------

# %%
def plot_and_pred(X_test, y_test, X_train, y_train, model) : 
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    metrices(y_test, y_pred)
    plot(y_test, y_pred)

# %% [markdown]
# ### Gausian NB

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
plot_and_pred(X_test_trees, y_test_trees, X_train_trees, y_train_trees, model = gnb)
# Out:
# r2 score : 0.2588227201936192
# MAE : 71448.26492248062
# RMSE : 99032.27734380636
# MSE : 9807391955.900581

# %% [markdown]
# ### ------------------Tree based algos---------------

# %% [markdown]
# ### 1. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
plot_and_pred(X_test_trees, y_test_trees, X_train_trees, y_train_trees, model = dtr)
# Out:
# r2 score : 0.6770221172669804
# MAE : 40643.49069767442
# RMSE : 65373.55596254783
# MSE : 4273701819.188372

# %% [markdown]
# ### 2. Random forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
plot_and_pred(X_test_trees, y_test_trees, X_train_trees, y_train_trees, model = rfr)
# Out:
# r2 score : 0.8168065578343209
# MAE : 31327.422916666666
# RMSE : 49234.6300255197
# MSE : 2424048793.749806

# %% [markdown]
# ### 3. Adaboost regressor

# %%
from sklearn.ensemble import AdaBoostRegressor
abr = AdaBoostRegressor()
plot_and_pred(X_test_trees, y_test_trees, X_train_trees, y_train_trees, model = abr)
# Out:
# r2 score : 0.4996903246017502
# MAE : 69085.60759962526
# RMSE : 81364.53899274356
# MSE : 6620188205.501687

# %% [markdown]
# ### 4. Graident boost regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
plot_and_pred(X_test_trees, y_test_trees, X_train_trees, y_train_trees, model = gbr)
# Out:
# r2 score : 0.7710954073496845
# MAE : 37856.67991853368
# RMSE : 55035.506838100395
# MSE : 3028907012.926595

# %% [markdown]
# ### -------------ANN--------------

# %%
import keras
from keras.layers import Dense, Dropout
from keras.models import Sequential

# %%
model = Sequential()

# %%
model.add(Dense(128, activation = 'relu', kernel_initializer = 'he_uniform', input_dim = X_train_distance.shape[1]))
model.add(Dropout(0.30))
model.add(Dense(256, activation = 'relu', kernel_initializer = 'he_normal'))
model.add(Dropout(0.30))
model.add(Dense(256, activation = 'relu', kernel_initializer = 'he_normal'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'MAE', metrics = ['mae'])
# Out:
# c:\Users\lenovo\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 116,609 (455.50 KB)
#  Trainable params: 116,609 (455.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train_distance, y_train_distance, batch_size = 128, epochs = 20, validation_split = 0.10)
# Out:
# Epoch 1/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.2452 - mae: 1.2452 - val_loss: 0.1772 - val_mae: 0.1772
# Epoch 2/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1999 - mae: 0.1999 - val_loss: 0.1668 - val_mae: 0.1668
# Epoch 3/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1620 - mae: 0.1620 - val_loss: 0.1536 - val_mae: 0.1536
# Epoch 4/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1509 - mae: 0.1509 - val_loss: 0.1567 - val_mae: 0.1567
# Epoch 5/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1452 - mae: 0.1452 - val_loss: 0.1476 - val_mae: 0.1476
# Epoch 6/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1441 - mae: 0.1441 - val_loss: 0.1492 - val_mae: 0.1492
# Epoch 7/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1352 - mae: 0.1352 - val_loss: 0.1342 - val_mae: 0.1342
# Epoch 8/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1330 - mae: 0.1330 - val_loss: 0.1290 - val_mae: 0.1290
# Epoch 9/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1306 - mae: 0.1306 - val_loss: 0.1431 - val_mae: 0.1431
# Epoch 10/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1251 - mae: 0.1251 - val_loss: 0.1384 - val_mae: 0.1384
# Epoch 11/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1237 - mae: 0.1237 - val_loss: 0.1356 - val_mae: 0.1356
# Epoch 12/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1209 - mae: 0.1209 - val_loss: 0.1385 - val_mae: 0.1385
# Epoch 13/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1196 - mae: 0.1196 - val_loss: 0.1422 - val_mae: 0.1422
# Epoch 14/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1197 - mae: 0.1197 - val_loss: 0.1365 - val_mae: 0.1365
# Epoch 15/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1174 - mae: 0.1174 - val_loss: 0.1338 - val_mae: 0.1338
# Epoch 16/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1147 - mae: 0.1147 - val_loss: 0.1238 - val_mae: 0.1238
# Epoch 17/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1157 - mae: 0.1157 - val_loss: 0.1282 - val_mae: 0.1282
# Epoch 18/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1132 - mae: 0.1132 - val_loss: 0.1215 - val_mae: 0.1215
# Epoch 19/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1125 - mae: 0.1125 - val_loss: 0.1230 - val_mae: 0.1230
# Epoch 20/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1126 - mae: 0.1126 - val_loss: 0.1307 - val_mae: 0.1307

# %%
y_pred_ann = model.predict(X_test_distance)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_pred_ann = scaler.inverse_transform(np.array(y_pred_ann).reshape(-1, 1))
y_test_distance = scaler.inverse_transform(np.array(y_test_distance).reshape(-1, 1))

# %%
metrices(y_test_distance, y_pred_ann)
# Out:
# r2 score : 0.3888625390443404
# MAE : 63791.55605922965
# RMSE : 89925.97805568544
# MSE : 8086681529.271618

# %%
plot(y_test_distance, y_pred_ann)
